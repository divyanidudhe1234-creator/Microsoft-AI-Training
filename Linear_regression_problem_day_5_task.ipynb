# %%
import pandas as pd

# %%
df=pd.read_csv("/content/student performance prediction.csv")

# %%
df.head(20)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.shape
# Out:
# (1000, 8)

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
x = df['math score']
y = df['reading score']
plt.scatter(x, y)
plt.xlabel('Math Score')
plt.ylabel('Reading Score')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((800,), (200,), (800,), (200,))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# Reshape x_train to be 2D as required by fit method
lr.fit(x_train.to_numpy().reshape(-1, 1), y_train)

print("Model fitted successfully!")
# Out:
# Model fitted successfully!

# %%
score = lr.score(x_test.to_numpy().reshape(-1, 1), y_test) * 100
print(f"Model R-squared score: {score:.2f}%")
# Out:
# Model R-squared score: 70.00%

# %%
lr=LinearRegression()
lr.fit(x_train.to_numpy().reshape(-1, 1),y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train.to_numpy().reshape(-1, 1),y_train)*100
# Out:
# 65.99968915132659

# %%
lr.coef_
# Out:
# array([0.78914241])

# %%
lr.intercept_
# Out:
# np.float64(16.73356415749044)

# %%
lr.predict([[6]])
# Out:
# array([21.4684186])

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x.to_numpy().reshape(-1, 1)),color='red')
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# %%
mse=mean_squared_error(y_test,lr.predict(x_test.to_numpy().reshape(-1, 1)))
print(mse)
# Out:
# 64.22889213956107

# %% [markdown]
# **TASK**
#
# Convert linear regression into nonlinear regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# X aur y
X = df[['math score']]
y = df['reading score']

# Polynomial Features
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# Linear Regression model
lr = LinearRegression()
lr.fit(X_poly, y)

# Prediction
y_pred = lr.predict(X_poly)

# %%
import matplotlib.pyplot as plt

plt.scatter(X, y)
plt.plot(X, y_pred, color="black", linestyle="dashed")

plt.xlabel('Math Score')
plt.ylabel('Reading Score')
plt.show()
